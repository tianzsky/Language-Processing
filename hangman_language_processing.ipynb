# %% [markdown]
# ## Hangman Game
# Write an algorithm that plays the game of Hangman.
#
# If the user guesses a letter that is in the word, the word is redisplayed with all instances of that letter shown in the correct positions, along with any letters correctly guessed on previous turns. If the letter does not appear in the word, the user is charged with an incorrect guess. The user keeps guessing letters until either (1) the user has correctly guessed all the letters in the word
# or (2) the user has made six incorrect guesses.
#
# I use a training set of approximately 250,000 dictionary words. My algorithm will improve the successful rate to 69.57%

# %%
import random
import string
import time
import re
import collections

# %%
from collections import *
from math import *
from sklearn.model_selection import train_test_split
from itertools import combinations

# %% [markdown]
# ### Language Model to train the dictionary
# 1. Get the probablity of letter appearance in differenet combination of gram
# 2. Hyper-parameter order decide the length of gram
#
#         ## add different combination of gram into the trained language model
#         ## e.g. apple with order = 3, grams = "app","ppl","ple"
#         ## for gram "app" below will be added into language model with the appearance of letter probability
#         ## ap_, _pp, a_p
#         ## a__, _p_, __p

# %%
def update_counter(lm, data, order):
    for i in range(len(data)-order):
        history, char = data[i:i+order], data[i+order]
        if history.find(' ') == -1 and char != ' ':
            lm[history][char]+=1
    return lm

def train_char_lm(dic, order=3):
    lm = defaultdict(Counter)
    data = dic
    # calculate the probability of letter appearnce in a specified gram (length decided by order)
    for i in range(len(data)-order):
        gram = data[i:i+order]
        histories = []
        chars = []
        if gram.find(' ') == -1 and gram.find('_') == -1:
            replace_space = order - 1
            while(replace_space>0):
                gram_list = list(gram)
                comb = combinations(range(len(gram)), replace_space)
                for i in list(comb):
                    keeped_letter = [x if idx not in list(i) else '_' for idx, x in enumerate(gram_list)]
                    replaced_letter = [x for idx, x in enumerate(gram_list) if idx in list(i)]
                    histories += ["".join(keeped_letter)]
                    chars += [Counter("".join(replaced_letter)).most_common()[0][0]]               
                replace_space -= 1
        for history, char in zip(histories, chars):
            if history.find(' ') == -1 and char != ' ':
                lm[history][char]+=1
    
    def normalize(counter):
        s = float(sum(counter.values()))
        return [(c,cnt/s) for c,cnt in counter.items()]
    outlm = {hist:normalize(chars) for hist, chars in lm.items()}
    return outlm

# %%
def check_guessed(sorted_letter_count, guessed_letters):
    flag = False
    for letter, instance_prob in sorted_letter_count:
        if letter not in guessed_letters and letter is not '_':
            flag = True
            break
    if flag:
        return (letter, instance_prob)
    else:
        return

def update_candidate(candidate_list, curr_guess):
    if curr_guess is not None:
        if curr_guess[0] in candidate_list:
            candidate_list[curr_guess[0]] += curr_guess[1]
        else:
            candidate_list[curr_guess[0]] = curr_guess[1]
    return candidate_list

def generate_letter(full_dict, guess, lm, d, guessed_letters, order = 3):
    candidate_list = {} 
    print (guess)
     ## the first time guess is based on probablity of all words with the length of target word
    if len(set(guess))== 1 and guess[0] == '_':
        curr_guess = check_guessed(collections.Counter("".join(d[len(guess)])).most_common(), guessed_letters)
        candidate_list = update_candidate(candidate_list, curr_guess)
    
    ## get the gram of current word and get the probablity of letters from language model
    for i in range(len(guess)):
        stem = guess[i:i+order]
        if stem in lm:
            curr_guess = check_guessed(sorted(lm[stem], key=lambda item:item[1], reverse=True), guessed_letters)
            candidate_list = update_candidate(candidate_list, curr_guess)
            
    ## if the gram is not in the language model, then use the default probability of all words with the length of target word
    if (len(candidate_list) == 0):
        curr_guess = check_guessed(collections.Counter("".join(d[len(guess)])).most_common(), guessed_letters)
        candidate_list = update_candidate(candidate_list, curr_guess)
        
    letter = max(candidate_list, key=lambda k: candidate_list[k])
    return letter

def play(answer, lm,  d, order, nTrials=6):
    guess = "_ " * int(len(answer)/2)
    guess_clean = guess[::2].replace(" ", "")
    full_dict = full_dictionary
    guessed_letters = []
    errors = 0
    count = 0
    flag = False
    while(errors < nTrials):
        c = generate_letter(full_dict, guess_clean, lm, d, guessed_letters, order)
        guessed_letters += [c]
        if answer.find(c)!=-1:
            idx = [pos for pos, char in enumerate(answer) if char == c]
            for j in idx:
                guess = '%s%s%s'%(guess[:j],c,guess[j+1:])
        else:
            errors += 1
        print ("-------------")   
        print (count, errors, c, ':  ', guess_clean)
        print ("-------------")
        guess_clean = guess[::2]
        if guess_clean.find('_') == -1:
            flag = True
            break
        count += 1
    return guess, flag

# %% [markdown]
# ### Load the dictionary

# %%
def build_dictionary(dictionary_file_location):
    text_file = open(dictionary_file_location,"r")
    full_dictionary = text_file.read().splitlines()
    text_file.close()
    return full_dictionary

full_dictionary_location = "words_250000_train.txt"
full_dictionary = build_dictionary(full_dictionary_location)

# %% [markdown]
# ### Train the Language Model

# %%
full_dic, answers = train_test_split(full_dictionary, test_size = 0.0001)
lm = train_char_lm(" ".join(full_dic), 5)
d=defaultdict(list)
for word in full_dic:
    d[len(word)].append(word)

# %% [markdown]
# ### Start the Game

# %%
N = len(answers)
success = 0
for answer in answers:
    answer = " ".join(answer) + " "
    res, flag = play(answer, lm, d, order = 5)
    if flag:
        success += 1
        print ("success!, the answer is " + res)
    else:
        print("failed!, the answer is " + answer + " the guess is " + res)
# Out:
# _______
# -------------
# (0, 0, 'e', ':  ', '_______')
# -------------
# ____e__
# -------------
# (1, 1, 'i', ':  ', '____e__')
# -------------
# ____e__
# -------------
# (2, 2, 'a', ':  ', '____e__')
# -------------
# ____e__
# -------------
# (3, 2, 's', ':  ', '____e__')
# -------------
# ____e_s
# -------------
# (4, 2, 'r', ':  ', '____e_s')
# -------------
# ____ers
# -------------
# (5, 3, 'p', ':  ', '____ers')
# -------------
# ____ers
# -------------
# (6, 3, 'o', ':  ', '____ers')
# -------------
# _o__ers
# -------------
# (7, 3, 'h', ':  ', '_o__ers')
# -------------
# ho__ers
# -------------
# (8, 4, 'l', ':  ', 'ho__ers')
# -------------
# ho__ers
# -------------
# (9, 5, 'd', ':  ', 'ho__ers')
# -------------
# ho__ers
# -------------
# (10, 6, 't', ':  ', 'ho__ers')
# -------------
# failed!, the answer is h o c k e r s  the guess is h o _ _ e r s
# __________
# -------------
# (0, 0, 'e', ':  ', '__________')
# -------------
# e_________
# -------------
# (1, 0, 'i', ':  ', 'e_________')
# -------------
# e____i____
# -------------
# (2, 1, 'a', ':  ', 'e____i____')
# -------------
# e____i____
# -------------
# (3, 1, 's', ':  ', 'e____i____')
# -------------
# e____is__s
# -------------
# (4, 2, 'h', ':  ', 'e____is__s')
# -------------
# e____is__s
# -------------
# (5, 3, 'r', ':  ', 'e____is__s')
# -------------
# e____is__s
# -------------
# (6, 4, 'p', ':  ', 'e____is__s')
# -------------
# e____is__s
# -------------
# (7, 5, 'c', ':  ', 'e____is__s')
# -------------
# e____is__s
# -------------
# (8, 5, 'm', ':  ', 'e____is__s')
# -------------
# em___ism_s
# -------------
# (9, 5, 'u', ':  ', 'em___ism_s')
# -------------
# em___ismus
# -------------
# (10, 5, 'b', ':  ', 'em___ismus')
# -------------
# emb__ismus
# -------------
# (11, 5, 'l', ':  ', 'emb__ismus')
# -------------
# emb_lismus
# -------------
# (12, 5, 'o', ':  ', 'emb_lismus')
# -------------
# success!, the answer is e m b o l i s m u s
# __________
# -------------
# (0, 0, 'e', ':  ', '__________')
# -------------
# ___e___e__
# -------------
# (1, 1, 'i', ':  ', '___e___e__')
# -------------
# ___e___e__
# -------------
# (2, 1, 'a', ':  ', '___e___e__')
# -------------
# _a_e___e__
# -------------
# (3, 1, 'r', ':  ', '_a_e___e__')
# -------------
# _a_er__e__
# -------------
# (4, 1, 's', ':  ', '_a_er__e__')
# -------------
# _a_ers_e_s
# -------------
# (5, 2, 'p', ':  ', '_a_ers_e_s')
# -------------
# _a_ers_e_s
# -------------
# (6, 2, 't', ':  ', '_a_ers_e_s')
# -------------
# _aters_e_s
# -------------
# (7, 2, 'w', ':  ', '_aters_e_s')
# -------------
# waters_e_s
# -------------
# (8, 2, 'h', ':  ', 'waters_e_s')
# -------------
# watershe_s
# -------------
# (9, 3, 'l', ':  ', 'watershe_s')
# -------------
# watershe_s
# -------------
# (10, 3, 'd', ':  ', 'watershe_s')
# -------------
# success!, the answer is w a t e r s h e d s
# _______________
# -------------
# (0, 0, 'i', ':  ', '_______________')
# -------------
# i________i_____
# -------------
# (1, 0, 'a', ':  ', 'i________i_____')
# -------------
# i___a____i___a_
# -------------
# (2, 0, 'r', ':  ', 'i___a____i___a_')
# -------------
# i__ra____i___ar
# -------------
# (3, 0, 's', ':  ', 'i__ra____i___ar')
# -------------
# i__ra__s_i___ar
# -------------
# (4, 0, 'e', ':  ', 'i__ra__s_i___ar')
# -------------
# i__ra_es_i___ar
# -------------
# (5, 0, 't', ':  ', 'i__ra_es_i___ar')
# -------------
# i_tratesti___ar
# -------------
# (6, 0, 'n', ':  ', 'i_tratesti___ar')
# -------------
# intratesti___ar
# -------------
# (7, 0, 'c', ':  ', 'intratesti___ar')
# -------------
# intratestic__ar
# -------------
# (8, 0, 'u', ':  ', 'intratestic__ar')
# -------------
# intratesticu_ar
# -------------
# (9, 0, 'l', ':  ', 'intratesticu_ar')
# -------------
# success!, the answer is i n t r a t e s t i c u l a r
# _______
# -------------
# (0, 0, 'e', ':  ', '_______')
# -------------
# ______e
# -------------
# (1, 0, 'i', ':  ', '______e')
# -------------
# __i___e
# -------------
# (2, 1, 'a', ':  ', '__i___e')
# -------------
# __i___e
# -------------
# (3, 2, 's', ':  ', '__i___e')
# -------------
# __i___e
# -------------
# (4, 3, 'h', ':  ', '__i___e')
# -------------
# __i___e
# -------------
# (5, 3, 'r', ':  ', '__i___e')
# -------------
# __i__re
# -------------
# (6, 4, 'p', ':  ', '__i__re')
# -------------
# __i__re
# -------------
# (7, 4, 'c', ':  ', '__i__re')
# -------------
# c_i__re
# -------------
# (8, 4, 't', ':  ', 'c_i__re')
# -------------
# c_it_re
# -------------
# (9, 4, 'u', ':  ', 'c_it_re')
# -------------
# c_iture
# -------------
# (10, 5, 'l', ':  ', 'c_iture')
# -------------
# c_iture
# -------------
# (11, 6, 'n', ':  ', 'c_iture')
# -------------
# failed!, the answer is c o i t u r e  the guess is c _ i t u r e
# _________
# -------------
# (0, 0, 'e', ':  ', '_________')
# -------------
# __e__e___
# -------------
# (1, 0, 'i', ':  ', '__e__e___')
# -------------
# __e__e_i_
# -------------
# (2, 0, 's', ':  ', '__e__e_i_')
# -------------
# __e__esi_
# -------------
# (3, 0, 'r', ':  ', '__e__esi_')
# -------------
# __e_resi_
# -------------
# (4, 1, 'p', ':  ', '__e_resi_')
# -------------
# __e_resi_
# -------------
# (5, 2, 'a', ':  ', '__e_resi_')
# -------------
# __e_resi_
# -------------
# (6, 3, 'd', ':  ', '__e_resi_')
# -------------
# __e_resi_
# -------------
# (7, 3, 'o', ':  ', '__e_resi_')
# -------------
# o_eoresi_
# -------------
# (8, 4, 'h', ':  ', 'o_eoresi_')
# -------------
# o_eoresi_
# -------------
# (9, 4, 'l', ':  ', 'o_eoresi_')
# -------------
# oleoresi_
# -------------
# (10, 4, 'n', ':  ', 'oleoresi_')
# -------------
# success!, the answer is o l e o r e s i n
# _____
# -------------
# (0, 1, 'a', ':  ', '_____')
# -------------
# _____
# -------------
# (1, 1, 'e', ':  ', '_____')
# -------------
# ____e
# -------------
# (2, 2, 'i', ':  ', '____e')
# -------------
# ____e
# -------------
# (3, 3, 's', ':  ', '____e')
# -------------
# ____e
# -------------
# (4, 3, 'p', ':  ', '____e')
# -------------
# __p_e
# -------------
# (5, 3, 'r', ':  ', '__p_e')
# -------------
# __pre
# -------------
# (6, 4, 'u', ':  ', '__pre')
# -------------
# __pre
# -------------
# (7, 5, 'm', ':  ', '__pre')
# -------------
# __pre
# -------------
# (8, 6, 'x', ':  ', '__pre')
# -------------
# failed!, the answer is c y p r e  the guess is _ _ p r e
# ______
# -------------
# (0, 0, 'e', ':  ', '______')
# -------------
# _____e
# -------------
# (1, 0, 'i', ':  ', '_____e')
# -------------
# ___i_e
# -------------
# (2, 1, 'a', ':  ', '___i_e')
# -------------
# ___i_e
# -------------
# (3, 2, 's', ':  ', '___i_e')
# -------------
# ___i_e
# -------------
# (4, 3, 'r', ':  ', '___i_e')
# -------------
# ___i_e
# -------------
# (5, 4, 'c', ':  ', '___i_e')
# -------------
# ___i_e
# -------------
# (6, 4, 'p', ':  ', '___i_e')
# -------------
# __pi_e
# -------------
# (7, 5, 'm', ':  ', '__pi_e')
# -------------
# __pi_e
# -------------
# (8, 6, 'o', ':  ', '__pi_e')
# -------------
# failed!, the answer is u n p i l e  the guess is _ _ p i _ e
# __________
# -------------
# (0, 1, 'e', ':  ', '__________')
# -------------
# __________
# -------------
# (1, 1, 'i', ':  ', '__________')
# -------------
# _____i____
# -------------
# (2, 2, 'a', ':  ', '_____i____')
# -------------
# _____i____
# -------------
# (3, 2, 's', ':  ', '_____i____')
# -------------
# s____i____
# -------------
# (4, 2, 'p', ':  ', 's____i____')
# -------------
# sp___i____
# -------------
# (5, 3, 'r', ':  ', 'sp___i____')
# -------------
# sp___i____
# -------------
# (6, 4, 'h', ':  ', 'sp___i____')
# -------------
# sp___i____
# -------------
# (7, 5, 'c', ':  ', 'sp___i____')
# -------------
# sp___i____
# -------------
# (8, 5, 'l', ':  ', 'sp___i____')
# -------------
# sp___i__l_
# -------------
# (9, 5, 'y', ':  ', 'sp___i__l_')
# -------------
# sp___i__ly
# -------------
# (10, 5, 'g', ':  ', 'sp___i__ly')
# -------------
# sp__gi_gly
# -------------
# (11, 5, 'n', ':  ', 'sp__gi_gly')
# -------------
# sp_ngingly
# -------------
# (12, 5, 'o', ':  ', 'sp_ngingly')
# -------------
# success!, the answer is s p o n g i n g l y
# _____
# -------------
# (0, 1, 'a', ':  ', '_____')
# -------------
# _____
# -------------
# (1, 2, 'e', ':  ', '_____')
# -------------
# _____
# -------------
# (2, 3, 's', ':  ', '_____')
# -------------
# _____
# -------------
# (3, 3, 'o', ':  ', '_____')
# -------------
# ___o_
# -------------
# (4, 4, 'i', ':  ', '___o_')
# -------------
# ___o_
# -------------
# (5, 5, 'p', ':  ', '___o_')
# -------------
# ___o_
# -------------
# (6, 6, 'r', ':  ', '___o_')
# -------------
# failed!, the answer is v u c o m  the guess is _ _ _ o _
# ____
# -------------
# (0, 0, 'a', ':  ', '____')
# -------------
# _a__
# -------------
# (1, 1, 'e', ':  ', '_a__')
# -------------
# _a__
# -------------
# (2, 2, 'o', ':  ', '_a__')
# -------------
# _a__
# -------------
# (3, 2, 's', ':  ', '_a__')
# -------------
# _ass
# -------------
# (4, 3, 'i', ':  ', '_ass')
# -------------
# _ass
# -------------
# (5, 4, 'r', ':  ', '_ass')
# -------------
# _ass
# -------------
# (6, 5, 'l', ':  ', '_ass')
# -------------
# _ass
# -------------
# (7, 6, 't', ':  ', '_ass')
# -------------
# failed!, the answer is p a s s  the guess is _ a s s
# __________
# -------------
# (0, 1, 'e', ':  ', '__________')
# -------------
# __________
# -------------
# (1, 1, 'i', ':  ', '__________')
# -------------
# _____i____
# -------------
# (2, 2, 'a', ':  ', '_____i____')
# -------------
# _____i____
# -------------
# (3, 2, 's', ':  ', '_____i____')
# -------------
# s____i____
# -------------
# (4, 2, 'p', ':  ', 's____i____')
# -------------
# s___pi____
# -------------
# (5, 3, 'r', ':  ', 's___pi____')
# -------------
# s___pi____
# -------------
# (6, 4, 'c', ':  ', 's___pi____')
# -------------
# s___pi____
# -------------
# (7, 4, 'y', ':  ', 's___pi____')
# -------------
# s___pi___y
# -------------
# (8, 4, 'l', ':  ', 's___pi___y')
# -------------
# s___pi__ly
# -------------
# (9, 4, 'g', ':  ', 's___pi__ly')
# -------------
# s___pi_gly
# -------------
# (10, 4, 'n', ':  ', 's___pi_gly')
# -------------
# s___pingly
# -------------
# (11, 4, 'm', ':  ', 's___pingly')
# -------------
# s__mpingly
# -------------
# (12, 5, 'u', ':  ', 's__mpingly')
# -------------
# s__mpingly
# -------------
# (13, 5, 'o', ':  ', 's__mpingly')
# -------------
# s_ompingly
# -------------
# (14, 5, 't', ':  ', 's_ompingly')
# -------------
# success!, the answer is s t o m p i n g l y
# _________
# -------------
# (0, 0, 'e', ':  ', '_________')
# -------------
# ____e__e_
# -------------
# (1, 1, 'i', ':  ', '____e__e_')
# -------------
# ____e__e_
# -------------
# (2, 2, 'a', ':  ', '____e__e_')
# -------------
# ____e__e_
# -------------
# (3, 2, 's', ':  ', '____e__e_')
# -------------
# ____e__es
# -------------
# (4, 2, 'r', ':  ', '____e__es')
# -------------
# ____er_es
# -------------
# (5, 3, 'p', ':  ', '____er_es')
# -------------
# ____er_es
# -------------
# (6, 4, 'l', ':  ', '____er_es')
# -------------
# ____er_es
# -------------
# (7, 5, 't', ':  ', '____er_es')
# -------------
# ____er_es
# -------------
# (8, 6, 'h', ':  ', '____er_es')
# -------------
# failed!, the answer is c o m m e r c e s  the guess is _ _ _ _ e r _ e s
# ____________
# -------------
# (0, 1, 'e', ':  ', '____________')
# -------------
# ____________
# -------------
# (1, 1, 'i', ':  ', '____________')
# -------------
# ___i_i___i__
# -------------
# (2, 1, 'a', ':  ', '___i_i___i__')
# -------------
# _a_i_i_a_i__
# -------------
# (3, 1, 'c', ':  ', '_a_i_i_a_i__')
# -------------
# _a_ici_a_i__
# -------------
# (4, 1, 't', ':  ', '_a_ici_a_i__')
# -------------
# _atici_ati__
# -------------
# (5, 2, 'm', ':  ', '_atici_ati__')
# -------------
# _atici_ati__
# -------------
# (6, 2, 'o', ':  ', '_atici_ati__')
# -------------
# _atici_atio_
# -------------
# (7, 2, 'n', ':  ', '_atici_atio_')
# -------------
# _aticination
# -------------
# (8, 3, 'r', ':  ', '_aticination')
# -------------
# _aticination
# -------------
# (9, 4, 'b', ':  ', '_aticination')
# -------------
# _aticination
# -------------
# (10, 5, 'h', ':  ', '_aticination')
# -------------
# _aticination
# -------------
# (11, 6, 'l', ':  ', '_aticination')
# -------------
# failed!, the answer is v a t i c i n a t i o n  the guess is _ a t i c i n a t i o n
# _________
# -------------
# (0, 0, 'e', ':  ', '_________')
# -------------
# ____e__e_
# -------------
# (1, 0, 'i', ':  ', '____e__e_')
# -------------
# ____e_ie_
# -------------
# (2, 0, 'r', ':  ', '____e_ie_')
# -------------
# __r_erie_
# -------------
# (3, 0, 's', ':  ', '__r_erie_')
# -------------
# __rseries
# -------------
# (4, 0, 'u', ':  ', '__rseries')
# -------------
# _urseries
# -------------
# (5, 1, 'o', ':  ', '_urseries')
# -------------
# _urseries
# -------------
# (6, 1, 'n', ':  ', '_urseries')
# -------------
# success!, the answer is n u r s e r i e s
# ___________
# -------------
# (0, 0, 'e', ':  ', '___________')
# -------------
# e__________
# -------------
# (1, 0, 'i', ':  ', 'e__________')
# -------------
# e_i___i_i__
# -------------
# (2, 1, 'a', ':  ', 'e_i___i_i__')
# -------------
# e_i___i_i__
# -------------
# (3, 1, 's', ':  ', 'e_i___i_i__')
# -------------
# e_i___isi__
# -------------
# (4, 1, 'g', ':  ', 'e_i___isi__')
# -------------
# e_i___isi_g
# -------------
# (5, 1, 'n', ':  ', 'e_i___isi_g')
# -------------
# e_i___ising
# -------------
# (6, 2, 'r', ':  ', 'e_i___ising')
# -------------
# e_i___ising
# -------------
# (7, 3, 'l', ':  ', 'e_i___ising')
# -------------
# e_i___ising
# -------------
# (8, 4, 'd', ':  ', 'e_i___ising')
# -------------
# e_i___ising
# -------------
# (9, 5, 'h', ':  ', 'e_i___ising')
# -------------
# e_i___ising
# -------------
# (10, 5, 'p', ':  ', 'e_i___ising')
# -------------
# epi___ising
# -------------
# (11, 6, 'c', ':  ', 'epi___ising')
# -------------
# failed!, the answer is e p i t o m i s i n g  the guess is e p i _ _ _ i s i n g
# ________
# -------------
# (0, 0, 'e', ':  ', '________')
# -------------
# _e_____e
# -------------
# (1, 1, 'i', ':  ', '_e_____e')
# -------------
# _e_____e
# -------------
# (2, 1, 'a', ':  ', '_e_____e')
# -------------
# _ea_a__e
# -------------
# (3, 1, 'r', ':  ', '_ea_a__e')
# -------------
# _eara__e
# -------------
# (4, 1, 'n', ':  ', '_eara__e')
# -------------
# _earan_e
# -------------
# (5, 1, 'c', ':  ', '_earan_e')
# -------------
# _earance
# -------------
# (6, 1, 'b', ':  ', '_earance')
# -------------
# success!, the answer is b e a r a n c e
# _________
# -------------
# (0, 0, 'e', ':  ', '_________')
# -------------
# e_e____e_
# -------------
# (1, 1, 'i', ':  ', 'e_e____e_')
# -------------
# e_e____e_
# -------------
# (2, 1, 'a', ':  ', 'e_e____e_')
# -------------
# e_e__a_e_
# -------------
# (3, 2, 'r', ':  ', 'e_e__a_e_')
# -------------
# e_e__a_e_
# -------------
# (4, 3, 's', ':  ', 'e_e__a_e_')
# -------------
# e_e__a_e_
# -------------
# (5, 4, 'c', ':  ', 'e_e__a_e_')
# -------------
# e_e__a_e_
# -------------
# (6, 5, 'p', ':  ', 'e_e__a_e_')
# -------------
# e_e__a_e_
# -------------
# (7, 6, 'h', ':  ', 'e_e__a_e_')
# -------------
# failed!, the answer is e v e n w a y e d  the guess is e _ e _ _ a _ e _
# ________
# -------------
# (0, 0, 'e', ':  ', '________')
# -------------
# _____e_e
# -------------
# (1, 0, 'i', ':  ', '_____e_e')
# -------------
# ____ie_e
# -------------
# (2, 0, 'a', ':  ', '____ie_e')
# -------------
# _a__ie_e
# -------------
# (3, 0, 'r', ':  ', '_a__ie_e')
# -------------
# _a__iere
# -------------
# (4, 1, 't', ':  ', '_a__iere')
# -------------
# _a__iere
# -------------
# (5, 2, 'l', ':  ', '_a__iere')
# -------------
# _a__iere
# -------------
# (6, 2, 'p', ':  ', '_a__iere')
# -------------
# pa__iere
# -------------
# (7, 2, 's', ':  ', 'pa__iere')
# -------------
# pa_siere
# -------------
# (8, 2, 'n', ':  ', 'pa_siere')
# -------------
# success!, the answer is p a n s i e r e
# ___________
# -------------
# (0, 1, 'e', ':  ', '___________')
# -------------
# ___________
# -------------
# (1, 1, 'i', ':  ', '___________')
# -------------
# _________i_
# -------------
# (2, 1, 'a', ':  ', '_________i_')
# -------------
# _______a_ia
# -------------
# (3, 1, 'r', ':  ', '_______a_ia')
# -------------
# _______aria
# -------------
# (4, 1, 't', ':  ', '_______aria')
# -------------
# ___t___aria
# -------------
# (5, 2, 'l', ':  ', '___t___aria')
# -------------
# ___t___aria
# -------------
# (6, 3, 'n', ':  ', '___t___aria')
# -------------
# ___t___aria
# -------------
# (7, 4, 'c', ':  ', '___t___aria')
# -------------
# ___t___aria
# -------------
# (8, 5, 'u', ':  ', '___t___aria')
# -------------
# ___t___aria
# -------------
# (9, 5, 'h', ':  ', '___t___aria')
# -------------
# _h_t___aria
# -------------
# (10, 5, 'o', ':  ', '_h_t___aria')
# -------------
# _h_to_oaria
# -------------
# (11, 5, 'z', ':  ', '_h_to_oaria')
# -------------
# _h_tozoaria
# -------------
# (12, 5, 'p', ':  ', '_h_tozoaria')
# -------------
# ph_tozoaria
# -------------
# (13, 5, 'y', ':  ', 'ph_tozoaria')
# -------------
# success!, the answer is p h y t o z o a r i a
# ________
# -------------
# (0, 0, 'e', ':  ', '________')
# -------------
# _e______
# -------------
# (1, 0, 'i', ':  ', '_e______')
# -------------
# _e__i___
# -------------
# (2, 0, 'a', ':  ', '_e__i___')
# -------------
# _e_ai_a_
# -------------
# (3, 1, 't', ':  ', '_e_ai_a_')
# -------------
# _e_ai_a_
# -------------
# (4, 2, 'b', ':  ', '_e_ai_a_')
# -------------
# _e_ai_a_
# -------------
# (5, 3, 'r', ':  ', '_e_ai_a_')
# -------------
# _e_ai_a_
# -------------
# (6, 4, 'l', ':  ', '_e_ai_a_')
# -------------
# _e_ai_a_
# -------------
# (7, 4, 's', ':  ', '_e_ai_a_')
# -------------
# _e_ai_as
# -------------
# (8, 4, 'd', ':  ', '_e_ai_as')
# -------------
# _e_aidas
# -------------
# (9, 5, 'm', ':  ', '_e_aidas')
# -------------
# _e_aidas
# -------------
# (10, 6, 'p', ':  ', '_e_aidas')
# -------------
# failed!, the answer is z e n a i d a s  the guess is _ e _ a i d a s
# __________
# -------------
# (0, 0, 'e', ':  ', '__________')
# -------------
# _e___e__e_
# -------------
# (1, 0, 'i', ':  ', '_e___e__e_')
# -------------
# _e__ie__e_
# -------------
# (2, 1, 's', ':  ', '_e__ie__e_')
# -------------
# _e__ie__e_
# -------------
# (3, 1, 'r', ':  ', '_e__ie__e_')
# -------------
# _e_rie__e_
# -------------
# (4, 2, 't', ':  ', '_e_rie__e_')
# -------------
# _e_rie__e_
# -------------
# (5, 3, 'a', ':  ', '_e_rie__e_')
# -------------
# _e_rie__e_
# -------------
# (6, 4, 'c', ':  ', '_e_rie__e_')
# -------------
# _e_rie__e_
# -------------
# (7, 5, 'm', ':  ', '_e_rie__e_')
# -------------
# _e_rie__e_
# -------------
# (8, 6, 'p', ':  ', '_e_rie__e_')
# -------------
# failed!, the answer is b e f r i e n d e d  the guess is _ e _ r i e _ _ e _
# _____
# -------------
# (0, 0, 'a', ':  ', '_____')
# -------------
# a____
# -------------
# (1, 1, 'i', ':  ', 'a____')
# -------------
# a____
# -------------
# (2, 1, 's', ':  ', 'a____')
# -------------
# a___s
# -------------
# (3, 2, 'r', ':  ', 'a___s')
# -------------
# a___s
# -------------
# (4, 3, 'e', ':  ', 'a___s')
# -------------
# a___s
# -------------
# (5, 4, 'u', ':  ', 'a___s')
# -------------
# a___s
# -------------
# (6, 4, 'c', ':  ', 'a___s')
# -------------
# ac__s
# -------------
# (7, 5, 'h', ':  ', 'ac__s')
# -------------
# ac__s
# -------------
# (8, 5, 'y', ':  ', 'ac__s')
# -------------
# ac_ys
# -------------
# (9, 5, 'l', ':  ', 'ac_ys')
# -------------
# success!, the answer is a c l y s

# %%
acc = success/(N*1.0)*100
print ("success rate is %0.2f%%"%acc)
# Out:
# success rate is 47.83%
